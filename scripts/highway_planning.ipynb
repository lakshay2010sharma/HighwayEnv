# %% [markdown]
# # Behavioural Planning for Autonomous Highway Driving
#
# We plan a trajectory using the _Optimistic Planning for Deterministic systems_ ([OPD](https://hal.inria.fr/hal-00830182)) algorithm.

# %%
#@title Imports for env, agent, and visualisation.
# Environment
# !pip install highway-env
import gymnasium as gym
import highway_env

# Agent
# !pip install git+https://github.com/eleurent/rl-agents#egg=rl-agents
from rl_agents.agents.common.factory import agent_factory

# Visualisation
import sys
from tqdm.notebook import trange
# !pip install moviepy -U
# !pip install imageio_ffmpeg
# !pip install pyvirtualdisplay
# !sudo apt-get install -y xvfb python3-opengl ffmpeg
# !git clone https://github.com/eleurent/highway-env.git
sys.path.insert(0, './highway-env/scripts/')
from utils import record_videos, show_videos

# %%
import highway_env
highway_env.register_highway_envs()
from highway_env.envs.highway_two_way_env import *
gym.envs.register(
    id='highway-two-way-v0',
    entry_point='highway_env.envs:HighwayTwoWayEnv',
)
env = gym.make('highway-v0', render_mode="rgb_array")
env = record_videos(env)
env.configure({"vehicles_density": 2.5, "right_lane_reward": 0.1})
(obs, info), done = env.reset(), False

# Make agent
agent_config = {
    "__class__": "<class 'rl_agents.agents.tree_search.deterministic.DeterministicPlannerAgent'>",
    "env_preprocessors": [{"method":"simplify"}],
    "budget": 50,
    "gamma": 0.7,
}
agent = agent_factory(env, agent_config)

# Run episode
for step in trange(env.unwrapped.config["duration"], desc="Running..."):
    action = agent.act(obs)
    obs, reward, done, truncated, info = env.step(action)
    
env.close()
show_videos()
# Out:
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment exit-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment highway-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment highway-fast-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment highway-two-way-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment intersection-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment intersection-v1 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment intersection-multi-agent-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment intersection-multi-agent-v1 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment lane-keeping-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment merge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment parking-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment parking-ActionRepeat-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment parking-parked-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment racetrack-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment roundabout-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment two-way-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment u-turn-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:42: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (5, 5)
#   logger.warn(
# /home/lakshays/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/gymnasium/wrappers/record_video.py:87: UserWarning: WARN: Overwriting existing videos at /home/lakshays/stuff/HighwayEnv/scripts/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Running...:   0%|          | 0/40 [00:00<?, ?it/s]
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Moviepy - Building video /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# Expanding a terminal state
# <video alt="videos/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
#@title Run an episode

import gymnasium as gym
import highway_env
# highway_env.register_highway_envs()
from rl_agents.agents.common.factory import agent_factory
import sys
from tqdm.notebook import trange
sys.path.insert(0, './highway-env/scripts/')
from utils import record_videos, show_videos

# Make environment
env = gym.make("two-way-v0", render_mode="rgb_array")
print(env.road)
(obs, info), done = env.reset(), False
env = record_videos(env)
# env.configure({"vehicles_density": 3, "left_lane_reward": -0.2, "right_lane_reward": 0.2, "lanes_count": 2})
(obs, info), done = env.reset(), False

# Make agent
agent_config = {
    "__class__": "<class 'rl_agents.agents.tree_search.deterministic.DeterministicPlannerAgent'>",
    "env_preprocessors": [{"method":"simplify"}],
    "budget": 50,
    "gamma": 0.7,
}
agent = agent_factory(env, agent_config)

# Run episode
# for step in trange(env.unwrapped.config["duration"], desc="Running..."):
for step in trange(40, desc="Running..."):
    action = agent.act(obs)
    obs, reward, done, truncated, info = env.step(action)
    
env.close()
show_videos()
# Out:
# [MDPVehicle #824: [30.  4.], IDMVehicle #856: [68.31410116  4.        ], IDMVehicle #312: [95.75696018  4.        ], IDMVehicle #904: [157.25906281   4.        ], IDMVehicle #152: [602.4671922   0.       ], IDMVehicle #672: [509.67388237   0.        ]]
# Running...:   0%|          | 0/40 [00:00<?, ?it/s]
# Moviepy - Building video /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /home/lakshays/stuff/HighwayEnv/scripts/videos/rl-video-episode-0.mp4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 32
#      29 # Run episode
#      30 # for step in trange(env.unwrapped.config["duration"], desc="Running..."):
#      31 for step in trange(40, desc="Running..."):
# ---> 32     action = agent.act(obs)
#      33     obs, reward, done, truncated, info = env.step(action)
#      35 env.close()
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/abstract.py:96, in AbstractTreeSearchAgent.act(self, state)
#      95 def act(self, state):
# ---> 96     return self.plan(state)[0]
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/abstract.py:62, in AbstractTreeSearchAgent.plan(self, observation)
#      60 if replanning_required:
#      61     env = preprocess_env(self.env, self.config["env_preprocessors"])
# ---> 62     actions = self.planner.plan(state=env, observation=observation)
#      63 else:
#      64     actions = self.previous_actions[1:]
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/deterministic.py:120, in OptimisticDeterministicPlanner.plan(self, state, observation)
#     118 for epoch in np.arange(self.config["budget"] // state.action_space.n):
#     119     logger.debug("Expansion {}/{}".format(epoch + 1, self.config["budget"] // state.action_space.n))
# --> 120     self.run()
#     122 return self.get_plan()
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/deterministic.py:113, in OptimisticDeterministicPlanner.run(self)
#     111 if leaf_to_expand.done:
#     112     logger.warning("Expanding a terminal state")
# --> 113 leaf_to_expand.expand()
#     114 leaf_to_expand.backup_to_root()
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/deterministic.py:41, in DeterministicNode.expand(self)
#      36 for action in actions:
#      37     self.children[action] = type(self)(self,
#      38                                        self.planner,
#      39                                        state=safe_deepcopy_env(self.state),
#      40                                        depth=self.depth + 1)
# ---> 41     observation, reward, done, truncated, info = self.planner.step(self.children[action].state, action)
#      42     self.planner.leaves.append(self.children[action])
#      43     self.children[action].update(reward, done, observation)
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/rl_agents/agents/tree_search/abstract.py:159, in AbstractPlanner.step(self, state, action)
#     158 def step(self, state, action):
# --> 159     step_data = state.step(action)
#     160     self.observations.append(step_data[0])
#     161     return step_data
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/highway_env-1.8.2-py3.8.egg/highway_env/envs/common/abstract.py:238, in AbstractEnv.step(self, action)
#     235 self._simulate(action)
#     237 obs = self.observation_type.observe()
# --> 238 reward = self._reward(action)
#     239 terminated = self._is_terminated()
#     240 truncated = self._is_truncated()
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/highway_env-1.8.2-py3.8.egg/highway_env/envs/two_way_env.py:47, in TwoWayEnv._reward(self, action)
#      41 def _reward(self, action: int) -> float:
#      42     """
#      43     The vehicle is rewarded for driving with high speed
#      44     :param action: the action performed
#      45     :return: the reward of the state-action transition
#      46     """
# ---> 47     return sum(self.config.get(name, 0) * reward for name, reward in self._rewards(action).items())
#
# File ~/stuff/HighwayEnv/.venv/lib/python3.8/site-packages/highway_env-1.8.2-py3.8.egg/highway_env/envs/two_way_env.py:53, in TwoWayEnv._rewards(self, action)
#      49 def _rewards(self, action: int) -> Dict[Text, float]:
#      50     neighbours = self.road.network.all_side_lanes(self.vehicle.lane_index)
#      51     return {
#      52         "high_speed_reward": self.vehicle.speed_index / (self.vehicle.target_speeds.size - 1),
# ---> 53         "left_lane_reward": (len(neighbours) - 1 - self.vehicle.target_lane_index[2]) / (len(neighbours) - 1),
#      54     }
#
# ZeroDivisionError: division by zero
